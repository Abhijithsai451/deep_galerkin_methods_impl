# %% [markdown]
# # Deep Galerkin Method with Elliptic PDE Example - Poisson Equation

# %%
from  DGM_Solver_Generalized import DGM_Solver_Generalized
from pde_residuals import *
from utility_functions import *
from visualize import *

# %% [markdown]
# ## Example for 1D poisson Equation

# %% [markdown]
# ### Parameters for 1D Poisson Equation

# %%
spatial_dim_1d = 1
lx_1d = 1.0
domain_bound_1d = [[0.0, lx_1d]]
poisson_pde_params_1d = {'f_func': f_func_1d}
num_pde_points = 5000
num_bc_points = 1000
epochs = 5000
learning_rate = 1e-2
layer_sizes = [32,32,32]

# %%
poisson_solver = DGM_Solver_Generalized(spatial_dim_1d,layer_sizes)
print("Created the Neural Model for 1D Poisson Equation ")
# Out:
# Using device: mps
# Created the Neural Model for 1D Poisson Equation

# %%
poisson_solver.train(pde_residual_func = poisson_equation_residual,
                         pde_parameters = poisson_pde_params_1d,
                         domain_bound = domain_bound_1d,
                         boundary_condition_func = bc_1d_poisson,
                         num_pde_points = num_pde_points,
                         num_bc_points = num_bc_points,
                         epochs = epochs, learning_rate = learning_rate
                         )
# Out:
#  --- Training Loop for DGM for 1 spatial dimensional pde on mps
# Epoch 0/5000: Total Loss=4.7739e+00, PDE Loss=4.0978e+00, BC Loss=6.7607e-01, IC Loss=0.0000e+00
# Epoch 500/5000: Total Loss=1.1334e-02, PDE Loss=8.5878e-03, BC Loss=2.7461e-03, IC Loss=0.0000e+00
# Epoch 1000/5000: Total Loss=2.7976e-02, PDE Loss=2.7395e-02, BC Loss=5.8119e-04, IC Loss=0.0000e+00
# Epoch 1500/5000: Total Loss=2.0703e-03, PDE Loss=2.0618e-03, BC Loss=8.5317e-06, IC Loss=0.0000e+00
# Epoch 2000/5000: Total Loss=2.4857e-03, PDE Loss=1.3922e-03, BC Loss=1.0935e-03, IC Loss=0.0000e+00
# Epoch 2500/5000: Total Loss=9.7059e-04, PDE Loss=7.5883e-04, BC Loss=2.1176e-04, IC Loss=0.0000e+00
# Epoch 3000/5000: Total Loss=6.0258e-04, PDE Loss=1.5383e-04, BC Loss=4.4875e-04, IC Loss=0.0000e+00
# Epoch 3500/5000: Total Loss=3.0148e-03, PDE Loss=2.8197e-03, BC Loss=1.9517e-04, IC Loss=0.0000e+00
# Epoch 4000/5000: Total Loss=1.9795e-03, PDE Loss=1.4853e-03, BC Loss=4.9415e-04, IC Loss=0.0000e+00
# Epoch 4500/5000: Total Loss=6.7090e-04, PDE Loss=6.6793e-04, BC Loss=2.9679e-06, IC Loss=0.0000e+00
# Epoch 4999/5000: Total Loss=3.5454e-03, PDE Loss=3.5298e-03, BC Loss=1.5634e-05, IC Loss=0.0000e+00
# Training complete.

# %% [markdown]
# ## Visualizing the Graphs

# %%
print("Visualizing the Poisson Equation Solution in 1D")
plot_1d_solution(poisson_solver, domain_bound_1d,
                             analytical_solution_func=analytical_solution_1d_poisson,
                             plot_params={'title': "1D Poisson: DGM vs Analytical"})
# Out:
# Visualizing the Poisson Equation Solution in 1D

# %% [markdown]
# # Poisson Equation 2D

# %% [markdown]
# ### Parameters for 2D Poisson Equation

# %%
spatial_dim_2d = 2
Lx_2d, Ly_2d = 1.0, 1.0
domain_bounds_2d = [[0.0, Lx_2d], [0.0, Ly_2d]]
num_pde_points = 10000
num_bc_points = 4000
epochs = 25000
learning_rate = 1e-3
layer_sizes = [64, 64, 64, 64, 32]
poisson_pde_params_2d = {'f_func': f_func_2d}

# %%
poisson_solver_2d = DGM_Solver_Generalized(spatial_dim_2d, layer_sizes=layer_sizes)
print("Created the Neural Model for 2D Poisson Equation ")
# Out:
# Using device: mps
# Created the Neural Model for 2D Poisson Equation

# %%
poisson_solver_2d.train(pde_residual_func=poisson_equation_residual,
                                pde_parameters=poisson_pde_params_2d,
                                domain_bound=domain_bounds_2d,
                                boundary_condition_func=bc_2d_poisson,
                                num_pde_points=num_pde_points, num_bc_points=num_bc_points,
                                epochs=epochs, learning_rate=learning_rate)
# Out:
#  --- Training Loop for DGM for 2 spatial dimensional pde on mps
# Epoch 0/25000: Total Loss=9.6677e+01, PDE Loss=9.6661e+01, BC Loss=1.5664e-02, IC Loss=0.0000e+00
# Epoch 2500/25000: Total Loss=3.1980e-01, PDE Loss=3.1077e-01, BC Loss=9.0322e-03, IC Loss=0.0000e+00
# Epoch 5000/25000: Total Loss=7.6910e-02, PDE Loss=7.6114e-02, BC Loss=7.9650e-04, IC Loss=0.0000e+00
# Epoch 7500/25000: Total Loss=5.6324e-02, PDE Loss=5.1294e-02, BC Loss=5.0301e-03, IC Loss=0.0000e+00
# Epoch 10000/25000: Total Loss=1.6927e-02, PDE Loss=1.6310e-02, BC Loss=6.1723e-04, IC Loss=0.0000e+00
# Epoch 12500/25000: Total Loss=1.1995e-02, PDE Loss=1.1744e-02, BC Loss=2.5099e-04, IC Loss=0.0000e+00
# Epoch 15000/25000: Total Loss=9.7396e-03, PDE Loss=7.4977e-03, BC Loss=2.2419e-03, IC Loss=0.0000e+00
# Epoch 17500/25000: Total Loss=7.9498e-03, PDE Loss=7.6987e-03, BC Loss=2.5110e-04, IC Loss=0.0000e+00
# Epoch 20000/25000: Total Loss=8.3279e-03, PDE Loss=8.0412e-03, BC Loss=2.8665e-04, IC Loss=0.0000e+00
# Epoch 22500/25000: Total Loss=5.1205e-03, PDE Loss=4.9947e-03, BC Loss=1.2584e-04, IC Loss=0.0000e+00
# Epoch 24999/25000: Total Loss=1.8087e-03, PDE Loss=1.7009e-03, BC Loss=1.0779e-04, IC Loss=0.0000e+00
# Training complete.

# %% [markdown]
# ## Visualizing the Graphs

# %%
plot_2d_solution_surface(poisson_solver_2d, domain_bounds=domain_bounds_2d,analytical_solution_func = analytical_solution_2d_poisson,plot_params= {'title':"DGM Solution for Sinπx*sinπy (2D Poisson Equation)"})

# %%
time_slices = [0.0, 0.25, 0.5, 0.75, 1.0]
plot_2d_solution_over_time_subplots(poisson_solver_2d, domain_bounds=domain_bounds_2d,time_slices=time_slices)
# Out:
# /Users/abhijithsai/PycharmProjects/deep_galerkin_impl/visualize.py:308: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %% [markdown]
# # Poisson Equation in 3D

# %%
spatial_dim_3d = 3
Lx_3d, Ly_3d, Lz_3d = 1.0, 1.0, 1.0
domain_bounds_3d = [[0.0, Lx_3d], [0.0, Ly_3d], [0.0, Lz_3d]]
num_pde_points = 15000
num_bc_points = 6000
epochs = 45000
learning_rate = 1e-3
layer_sizes = [128,128,128,64,32]
poisson_pde_params_3d = {'f_func': f_func_3d}

# %%
poisson_solver_3d = DGM_Solver_Generalized(spatial_dim_3d, layer_sizes=layer_sizes)
print("Created the Neural Model for 3D Poisson Equation ")
# Out:
# Using device: mps
# Created the Neural Model for 3D Poisson Equation

# %%
poisson_solver_3d.train(pde_residual_func=poisson_equation_residual,
                                pde_parameters=poisson_pde_params_3d,
                                domain_bound=domain_bounds_3d,
                                boundary_condition_func=bc_3d_poisson,
                                num_pde_points=num_pde_points, num_bc_points=num_bc_points,
                                epochs=epochs, learning_rate=learning_rate)
# Out:
#  --- Training Loop for DGM for 3 spatial dimensional pde on mps
# Epoch 0/45000: Total Loss=1.1214e+02, PDE Loss=1.1214e+02, BC Loss=4.4935e-03, IC Loss=0.0000e+00
# Epoch 4500/45000: Total Loss=1.8441e-01, PDE Loss=1.7880e-01, BC Loss=5.6142e-03, IC Loss=0.0000e+00
# Epoch 9000/45000: Total Loss=4.4187e-02, PDE Loss=4.3296e-02, BC Loss=8.9078e-04, IC Loss=0.0000e+00
# Epoch 13500/45000: Total Loss=3.4610e-02, PDE Loss=2.6912e-02, BC Loss=7.6978e-03, IC Loss=0.0000e+00
# Epoch 18000/45000: Total Loss=2.6284e-02, PDE Loss=2.1198e-02, BC Loss=5.0866e-03, IC Loss=0.0000e+00
# Epoch 22500/45000: Total Loss=3.1827e-02, PDE Loss=2.7133e-02, BC Loss=4.6932e-03, IC Loss=0.0000e+00
# Epoch 27000/45000: Total Loss=1.8283e-02, PDE Loss=1.7493e-02, BC Loss=7.8997e-04, IC Loss=0.0000e+00
# Epoch 31500/45000: Total Loss=9.6659e-03, PDE Loss=9.4468e-03, BC Loss=2.1910e-04, IC Loss=0.0000e+00
# Epoch 36000/45000: Total Loss=9.9075e-03, PDE Loss=9.6963e-03, BC Loss=2.1121e-04, IC Loss=0.0000e+00
# Epoch 40500/45000: Total Loss=6.1384e-03, PDE Loss=6.1107e-03, BC Loss=2.7711e-05, IC Loss=0.0000e+00
# Epoch 44999/45000: Total Loss=7.8579e-03, PDE Loss=7.8438e-03, BC Loss=1.4057e-05, IC Loss=0.0000e+00
# Training complete.

# %% [markdown]
# ## Visualizing the Graphs

# %%
plot_3d_solution_slice(poisson_solver_3d, fixed_coord_dim=2, fixed_coord_val=Lz_3d / 2,
                           domain_bounds=domain_bounds_3d, title="DGM 3D Poisson Slice for the analytical solution sinπx*sinπy*sinπz")

# %%
spatial_slices_3d_plot = [0.1, 0.25, 0.5, 0.75, 0.9]
plot_3d_solution_spatial_slices_subplots(poisson_solver_3d, fixed_coord_dim=2,
                                             fixed_coord_vals=spatial_slices_3d_plot,
                                             domain_bounds=domain_bounds_3d,
                                             plot_params={'title': "3D Poisson DGM Solution Slices along Z"})
# Out:
# /Users/abhijithsai/PycharmProjects/deep_galerkin_impl/visualize.py:442: UserWarning: Tight layout not applied. tight_layout cannot make Axes width small enough to accommodate all Axes decorations
#   plt.tight_layout(rect=[0, 0.03, 1, 0.95])
